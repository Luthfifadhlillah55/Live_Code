# %% [markdown]
# # Perkenalan
# Nama : Luthfi Fadhlillah
# (FTDS Batch 009)

# %% [markdown]
# # Membuat Data Baru Kasus Covid-19
# Instruksi:
# 1. Jumlah kasus kumulativ tertinggi pada tanggal 20 Januari 2022
# 2. Puncak tertinggi kasus harian di Indonesia

# %% [markdown]
# # Import Pustaka
# Melakukan import library/pustaka yang akan digunakan

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Data Loading
# Membuka data yang akan digunakan

# %%
data = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv')

# %%
data
# Out:
#     Province/State        Country/Region        Lat        Long  1/22/20  \
# 0              NaN           Afghanistan  33.939110   67.709953        0
# 1              NaN               Albania  41.153300   20.168300        0
# 2              NaN               Algeria  28.033900    1.659600        0
# 3              NaN               Andorra  42.506300    1.521800        0
# 4              NaN                Angola -11.202700   17.873900        0
# ..             ...                   ...        ...         ...      ...
# 279            NaN    West Bank and Gaza  31.952200   35.233200        0
# 280            NaN  Winter Olympics 2022  39.904200  116.407400        0
# 281            NaN                 Yemen  15.552727   48.516388        0
# 282            NaN                Zambia -13.133897   27.849332        0
# 283            NaN              Zimbabwe -19.015438   29.154857        0
#
#      1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  2/10/22  2/11/22  \
# 0          0        0        0        0        0  ...   169448   169940
# 1          0        0        0        0        0  ...   267020   267020
# 2          0        0        0        0        0  ...   260191   260723
# 3          0        0        0        0        0  ...    37074    37140
# 4          0        0        0        0        0  ...    98474    98501
# ..       ...      ...      ...      ...      ...  ...      ...      ...
# 279        0        0        0        0        0  ...   600128   600128
# 280        0        0        0        0        0  ...      465      490
# 281        0        0        0        0        0  ...    11604    11659
# 282        0        0        0        0        0  ...   308556   309013
# 283        0        0        0        0        0  ...   231040   231214
#
#      2/12/22  2/13/22  2/14/22  2/15/22  2/16/22  2/17/22  2/18/22  2/19/22
# 0     170152   170604   171246   171422   171519   171673   171857   171931
# 1     267551   268008   268304   268491   268940   269301   269601   269904
# 2     261226   261752   262165   262570   262994   263369   263685   263936
# 3      37140    37140    37277    37361    37452    37522    37589    37589
# 4      98514    98514    98514    98555    98568    98585    98605    98617
# ..       ...      ...      ...      ...      ...      ...      ...      ...
# 279   600128   600128   613846   618527   622175   625028   627956   627956
# 280      498      501      501      505      507      507      508      508
# 281    11664    11671    11679    11699    11707    11718    11731    11731
# 282   309293   309502   309579   309870   310155   310474   310764   311016
# 283   231299   231381   231603   231603   232213   232598   233030   233224
#
# [284 rows x 764 columns]

# %% [markdown]
# # Data Exploration
# Melakukan data eksplorasi pada datasheet secara sederhana.

# %%
data
# Out:
#     Province/State        Country/Region        Lat        Long  1/22/20  \
# 0              NaN           Afghanistan  33.939110   67.709953        0
# 1              NaN               Albania  41.153300   20.168300        0
# 2              NaN               Algeria  28.033900    1.659600        0
# 3              NaN               Andorra  42.506300    1.521800        0
# 4              NaN                Angola -11.202700   17.873900        0
# ..             ...                   ...        ...         ...      ...
# 279            NaN    West Bank and Gaza  31.952200   35.233200        0
# 280            NaN  Winter Olympics 2022  39.904200  116.407400        0
# 281            NaN                 Yemen  15.552727   48.516388        0
# 282            NaN                Zambia -13.133897   27.849332        0
# 283            NaN              Zimbabwe -19.015438   29.154857        0
#
#      1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  2/10/22  2/11/22  \
# 0          0        0        0        0        0  ...   169448   169940
# 1          0        0        0        0        0  ...   267020   267020
# 2          0        0        0        0        0  ...   260191   260723
# 3          0        0        0        0        0  ...    37074    37140
# 4          0        0        0        0        0  ...    98474    98501
# ..       ...      ...      ...      ...      ...  ...      ...      ...
# 279        0        0        0        0        0  ...   600128   600128
# 280        0        0        0        0        0  ...      465      490
# 281        0        0        0        0        0  ...    11604    11659
# 282        0        0        0        0        0  ...   308556   309013
# 283        0        0        0        0        0  ...   231040   231214
#
#      2/12/22  2/13/22  2/14/22  2/15/22  2/16/22  2/17/22  2/18/22  2/19/22
# 0     170152   170604   171246   171422   171519   171673   171857   171931
# 1     267551   268008   268304   268491   268940   269301   269601   269904
# 2     261226   261752   262165   262570   262994   263369   263685   263936
# 3      37140    37140    37277    37361    37452    37522    37589    37589
# 4      98514    98514    98514    98555    98568    98585    98605    98617
# ..       ...      ...      ...      ...      ...      ...      ...      ...
# 279   600128   600128   613846   618527   622175   625028   627956   627956
# 280      498      501      501      505      507      507      508      508
# 281    11664    11671    11679    11699    11707    11718    11731    11731
# 282   309293   309502   309579   309870   310155   310474   310764   311016
# 283   231299   231381   231603   231603   232213   232598   233030   233224
#
# [284 rows x 764 columns]

# %%
print('Jumlah row', data.shape[0], '\nJumlah column', data.shape[1])
# Out:
# Jumlah row 284
# Jumlah column 764

# %% [markdown]
# Dapat dilihat bahwa data ini memiliki 284 baris dan 764 column

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284 entries, 0 to 283
# Columns: 764 entries, Province/State to 2/19/22
# dtypes: float64(2), int64(760), object(2)
# memory usage: 1.7+ MB

# %% [markdown]
# Data ini memiliki 2 column dengan tipe data float, 760 column dengan tipe data integer, dan 2 column dengan tipe data object

# %%
data.describe().T
# Out:
#          count          mean           std       min          25%  \
# Lat      282.0  2.010637e+01  2.584145e+01  -71.9499     4.643279
# Long     282.0  2.195872e+01  7.589337e+01 -178.1165   -22.036550
# 1/22/20  284.0  1.961268e+00  2.640260e+01    0.0000     0.000000
# 1/23/20  284.0  2.306338e+00  2.649984e+01    0.0000     0.000000
# 1/24/20  284.0  3.313380e+00  3.299262e+01    0.0000     0.000000
# ...        ...           ...           ...       ...          ...
# 2/15/22  284.0  1.462300e+06  5.999364e+06    0.0000  7852.500000
# 2/16/22  284.0  1.470893e+06  6.017744e+06    0.0000  7902.500000
# 2/17/22  284.0  1.478046e+06  6.031356e+06    0.0000  7963.000000
# 2/18/22  284.0  1.484923e+06  6.046653e+06    0.0000  7986.750000
# 2/19/22  284.0  1.490334e+06  6.055395e+06    0.0000  7988.750000
#
#                   50%            75%           max
# Lat         21.607878      40.950592  7.170690e+01
# Long        20.921188      84.992575  1.780650e+02
# 1/22/20      0.000000       0.000000  4.440000e+02
# 1/23/20      0.000000       0.000000  4.440000e+02
# 1/24/20      0.000000       0.000000  5.490000e+02
# ...               ...            ...           ...
# 2/15/22  63176.500000  734449.750000  7.803619e+07
# 2/16/22  63193.500000  736980.250000  7.817436e+07
# 2/17/22  63193.500000  738947.500000  7.827570e+07
# 2/18/22  63234.000000  740284.250000  7.842352e+07
# 2/19/22  63528.500000  741032.000000  7.845708e+07
#
# [762 rows x 8 columns]

# %%
data
# Out:
#     Province/State        Country/Region        Lat        Long  1/22/20  \
# 0              NaN           Afghanistan  33.939110   67.709953        0
# 1              NaN               Albania  41.153300   20.168300        0
# 2              NaN               Algeria  28.033900    1.659600        0
# 3              NaN               Andorra  42.506300    1.521800        0
# 4              NaN                Angola -11.202700   17.873900        0
# ..             ...                   ...        ...         ...      ...
# 279            NaN    West Bank and Gaza  31.952200   35.233200        0
# 280            NaN  Winter Olympics 2022  39.904200  116.407400        0
# 281            NaN                 Yemen  15.552727   48.516388        0
# 282            NaN                Zambia -13.133897   27.849332        0
# 283            NaN              Zimbabwe -19.015438   29.154857        0
#
#      1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  2/10/22  2/11/22  \
# 0          0        0        0        0        0  ...   169448   169940
# 1          0        0        0        0        0  ...   267020   267020
# 2          0        0        0        0        0  ...   260191   260723
# 3          0        0        0        0        0  ...    37074    37140
# 4          0        0        0        0        0  ...    98474    98501
# ..       ...      ...      ...      ...      ...  ...      ...      ...
# 279        0        0        0        0        0  ...   600128   600128
# 280        0        0        0        0        0  ...      465      490
# 281        0        0        0        0        0  ...    11604    11659
# 282        0        0        0        0        0  ...   308556   309013
# 283        0        0        0        0        0  ...   231040   231214
#
#      2/12/22  2/13/22  2/14/22  2/15/22  2/16/22  2/17/22  2/18/22  2/19/22
# 0     170152   170604   171246   171422   171519   171673   171857   171931
# 1     267551   268008   268304   268491   268940   269301   269601   269904
# 2     261226   261752   262165   262570   262994   263369   263685   263936
# 3      37140    37140    37277    37361    37452    37522    37589    37589
# 4      98514    98514    98514    98555    98568    98585    98605    98617
# ..       ...      ...      ...      ...      ...      ...      ...      ...
# 279   600128   600128   613846   618527   622175   625028   627956   627956
# 280      498      501      501      505      507      507      508      508
# 281    11664    11671    11679    11699    11707    11718    11731    11731
# 282   309293   309502   309579   309870   310155   310474   310764   311016
# 283   231299   231381   231603   231603   232213   232598   233030   233224
#
# [284 rows x 764 columns]

# %% [markdown]
# - Berapa banyak data yang kasus kumulatif pada tanggal 20 Januari untuk negara-negara dengan latitude di bawah 0?

# %%
data[data['Lat'] < 0][['1/20/22']]
# Out:
#       1/20/22
# 4       95220
# 5          11
# 7     7576335
# 9       28472
# 10     919876
# 11       8219
# 12     298367
# 13      89043
# 14      23515
# 15     717692
# 16       1338
# 28     795087
# 30     243946
# 31   23595178
# 36      36868
# 58    1916522
# 94       7784
# 95      23244
# 96      84198
# 110    658045
# 116     68003
# 118     60509
# 121     47275
# 124     35189
# 125     14854
# 126    133617
# 130       454
# 132     45663
# 149   4277644
# 159    319379
# 160        37
# 168     31899
# 175     55827
# 176     83403
# 183     70094
# 191    221432
# 192    154897
# 199         2
# 200     15401
# 210     36446
# 211    516555
# 212   2780049
# 219    127227
# 223        13
# 229     34367
# 234        81
# 236   3572860
# 248     32393
# 250     19866
# 252         1
# 265        85
# 271         4
# 274    556163
# 276         7
# 282    299971
# 283    227552

# %%
data[data['Lat'] < 0][['1/20/22']].count()
# Out:
# 1/20/22    56
# dtype: int64

# %% [markdown]
# Ada 56 data negara-negara dengan latitude dibawah 0 untuk kasus kumulatif per tanggal 20 Januari 2022

# %% [markdown]
# # Answer
# Menampilkan 5 data teratas untuk melihat gambaran dataset

# %%
data.head()
# Out:
#   Province/State Country/Region       Lat       Long  1/22/20  1/23/20  \
# 0            NaN    Afghanistan  33.93911  67.709953        0        0
# 1            NaN        Albania  41.15330  20.168300        0        0
# 2            NaN        Algeria  28.03390   1.659600        0        0
# 3            NaN        Andorra  42.50630   1.521800        0        0
# 4            NaN         Angola -11.20270  17.873900        0        0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  ...  2/10/22  2/11/22  2/12/22  \
# 0        0        0        0        0  ...   169448   169940   170152
# 1        0        0        0        0  ...   267020   267020   267551
# 2        0        0        0        0  ...   260191   260723   261226
# 3        0        0        0        0  ...    37074    37140    37140
# 4        0        0        0        0  ...    98474    98501    98514
#
#    2/13/22  2/14/22  2/15/22  2/16/22  2/17/22  2/18/22  2/19/22
# 0   170604   171246   171422   171519   171673   171857   171931
# 1   268008   268304   268491   268940   269301   269601   269904
# 2   261752   262165   262570   262994   263369   263685   263936
# 3    37140    37277    37361    37452    37522    37589    37589
# 4    98514    98514    98555    98568    98585    98605    98617
#
# [5 rows x 764 columns]

# %%
data_baru = data[data['Lat'] < 0][['1/20/22']]

# %%
data_baru
# Out:
#       1/20/22
# 4       95220
# 5          11
# 7     7576335
# 9       28472
# 10     919876
# 11       8219
# 12     298367
# 13      89043
# 14      23515
# 15     717692
# 16       1338
# 28     795087
# 30     243946
# 31   23595178
# 36      36868
# 58    1916522
# 94       7784
# 95      23244
# 96      84198
# 110    658045
# 116     68003
# 118     60509
# 121     47275
# 124     35189
# 125     14854
# 126    133617
# 130       454
# 132     45663
# 149   4277644
# 159    319379
# 160        37
# 168     31899
# 175     55827
# 176     83403
# 183     70094
# 191    221432
# 192    154897
# 199         2
# 200     15401
# 210     36446
# 211    516555
# 212   2780049
# 219    127227
# 223        13
# 229     34367
# 234        81
# 236   3572860
# 248     32393
# 250     19866
# 252         1
# 265        85
# 271         4
# 274    556163
# 276         7
# 282    299971
# 283    227552

# %%
data_baru['1/20/22'].max()
# Out:
# 23595178

# %% [markdown]
# Data kasus tertinggi pada tanggal 20 Januari 2022 untuk negara dengan dibawah latitude 0 adalah sebesar 23595178

# %%
data[data['Lat'] < 0][['1/20/22', "Country/Region"]].max()
# Out:
# 1/20/22           23595178
# Country/Region    Zimbabwe
# dtype: object

# %% [markdown]
# Dari data diatas, negara Zimbabwe merupakan negara dengan kasus kumulatif paling tinggi pada tanggal 20 Januari 2022 untuk negara negara dengan latitude dibawah 0.

# %%
data.loc[data['Country/Region']=='Indonesia',:]['1/20/22']
# Out:
# 149    4277644
# Name: 1/20/22, dtype: int64

# %% [markdown]
# Data Indonesia pada tanggal 20 januari 2022 untuk kasus kumulatif adalah sebesar 4277644

# %%
data.head()
# Out:
#   Province/State Country/Region       Lat       Long  1/22/20  1/23/20  \
# 0            NaN    Afghanistan  33.93911  67.709953        0        0
# 1            NaN        Albania  41.15330  20.168300        0        0
# 2            NaN        Algeria  28.03390   1.659600        0        0
# 3            NaN        Andorra  42.50630   1.521800        0        0
# 4            NaN         Angola -11.20270  17.873900        0        0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  ...  2/10/22  2/11/22  2/12/22  \
# 0        0        0        0        0  ...   169448   169940   170152
# 1        0        0        0        0  ...   267020   267020   267551
# 2        0        0        0        0  ...   260191   260723   261226
# 3        0        0        0        0  ...    37074    37140    37140
# 4        0        0        0        0  ...    98474    98501    98514
#
#    2/13/22  2/14/22  2/15/22  2/16/22  2/17/22  2/18/22  2/19/22
# 0   170604   171246   171422   171519   171673   171857   171931
# 1   268008   268304   268491   268940   269301   269601   269904
# 2   261752   262165   262570   262994   263369   263685   263936
# 3    37140    37277    37361    37452    37522    37589    37589
# 4    98514    98514    98555    98568    98585    98605    98617
#
# [5 rows x 764 columns]

# %%
def Kasus_harian():
    "Menghitung kasus harian covid-19"
    Kasus = hari_ini - hari_kemarin
    return Kasus

# %%
data['Kasus harian'] = ''

# %%
data
# Out:
#     Province/State        Country/Region        Lat        Long  1/22/20  \
# 0              NaN           Afghanistan  33.939110   67.709953        0
# 1              NaN               Albania  41.153300   20.168300        0
# 2              NaN               Algeria  28.033900    1.659600        0
# 3              NaN               Andorra  42.506300    1.521800        0
# 4              NaN                Angola -11.202700   17.873900        0
# ..             ...                   ...        ...         ...      ...
# 279            NaN    West Bank and Gaza  31.952200   35.233200        0
# 280            NaN  Winter Olympics 2022  39.904200  116.407400        0
# 281            NaN                 Yemen  15.552727   48.516388        0
# 282            NaN                Zambia -13.133897   27.849332        0
# 283            NaN              Zimbabwe -19.015438   29.154857        0
#
#      1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  2/11/22  2/12/22  \
# 0          0        0        0        0        0  ...   169940   170152
# 1          0        0        0        0        0  ...   267020   267551
# 2          0        0        0        0        0  ...   260723   261226
# 3          0        0        0        0        0  ...    37140    37140
# 4          0        0        0        0        0  ...    98501    98514
# ..       ...      ...      ...      ...      ...  ...      ...      ...
# 279        0        0        0        0        0  ...   600128   600128
# 280        0        0        0        0        0  ...      490      498
# 281        0        0        0        0        0  ...    11659    11664
# 282        0        0        0        0        0  ...   309013   309293
# 283        0        0        0        0        0  ...   231214   231299
#
#      2/13/22  2/14/22  2/15/22  2/16/22  2/17/22  2/18/22  2/19/22  \
# 0     170604   171246   171422   171519   171673   171857   171931
# 1     268008   268304   268491   268940   269301   269601   269904
# 2     261752   262165   262570   262994   263369   263685   263936
# 3      37140    37277    37361    37452    37522    37589    37589
# 4      98514    98514    98555    98568    98585    98605    98617
# ..       ...      ...      ...      ...      ...      ...      ...
# 279   600128   613846   618527   622175   625028   627956   627956
# 280      501      501      505      507      507      508      508
# 281    11671    11679    11699    11707    11718    11731    11731
# 282   309502   309579   309870   310155   310474   310764   311016
# 283   231381   231603   231603   232213   232598   233030   233224
#
#      Kasus harian
# 0
# 1
# 2
# 3
# 4
# ..            ...
# 279
# 280
# 281
# 282
# 283
#
# [284 rows x 765 columns]

# %%
data['Kasus harian'] = data['2/19/22'] - data['2/18/22']

# %%
data['Kasus harian']
# Out:
# 0       74
# 1      303
# 2      251
# 3        0
# 4       12
#       ...
# 279      0
# 280      0
# 281      0
# 282    252
# 283    194
# Name: Kasus harian, Length: 284, dtype: int64

# %% [markdown]
# Data kasus harian pertanggal 20 Februari 2022

# %%
data
# Out:
#     Province/State        Country/Region        Lat        Long  1/22/20  \
# 0              NaN           Afghanistan  33.939110   67.709953        0
# 1              NaN               Albania  41.153300   20.168300        0
# 2              NaN               Algeria  28.033900    1.659600        0
# 3              NaN               Andorra  42.506300    1.521800        0
# 4              NaN                Angola -11.202700   17.873900        0
# ..             ...                   ...        ...         ...      ...
# 279            NaN    West Bank and Gaza  31.952200   35.233200        0
# 280            NaN  Winter Olympics 2022  39.904200  116.407400        0
# 281            NaN                 Yemen  15.552727   48.516388        0
# 282            NaN                Zambia -13.133897   27.849332        0
# 283            NaN              Zimbabwe -19.015438   29.154857        0
#
#      1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  2/11/22  2/12/22  \
# 0          0        0        0        0        0  ...   169940   170152
# 1          0        0        0        0        0  ...   267020   267551
# 2          0        0        0        0        0  ...   260723   261226
# 3          0        0        0        0        0  ...    37140    37140
# 4          0        0        0        0        0  ...    98501    98514
# ..       ...      ...      ...      ...      ...  ...      ...      ...
# 279        0        0        0        0        0  ...   600128   600128
# 280        0        0        0        0        0  ...      490      498
# 281        0        0        0        0        0  ...    11659    11664
# 282        0        0        0        0        0  ...   309013   309293
# 283        0        0        0        0        0  ...   231214   231299
#
#      2/13/22  2/14/22  2/15/22  2/16/22  2/17/22  2/18/22  2/19/22  \
# 0     170604   171246   171422   171519   171673   171857   171931
# 1     268008   268304   268491   268940   269301   269601   269904
# 2     261752   262165   262570   262994   263369   263685   263936
# 3      37140    37277    37361    37452    37522    37589    37589
# 4      98514    98514    98555    98568    98585    98605    98617
# ..       ...      ...      ...      ...      ...      ...      ...
# 279   600128   613846   618527   622175   625028   627956   627956
# 280      501      501      505      507      507      508      508
# 281    11671    11679    11699    11707    11718    11731    11731
# 282   309502   309579   309870   310155   310474   310764   311016
# 283   231381   231603   231603   232213   232598   233030   233224
#
#      Kasus harian
# 0              74
# 1             303
# 2             251
# 3               0
# 4              12
# ..            ...
# 279             0
# 280             0
# 281             0
# 282           252
# 283           194
#
# [284 rows x 765 columns]

# %%
data.loc[data['Country/Region']=='Indonesia',:].max()
# Out:
# Province/State         None
# Country/Region    Indonesia
# Lat                 -0.7893
# Long               113.9213
# 1/22/20                   0
#                     ...
# 2/16/22             4966046
# 2/17/22             5030002
# 2/18/22             5089637
# 2/19/22             5149021
# Kasus harian
# Length: 765, dtype: object

# %%
df = pd.DataFrame(data)

# %%
df.diff(axis=1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\ops\array_ops.py:163, in _na_arithmetic_op(left, right, op, is_cmp)
#     <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/ops/array_ops.py?line=161'>162</a> try:
# --> <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/ops/array_ops.py?line=162'>163</a>     result = func(left, right)
#     <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/ops/array_ops.py?line=163'>164</a> except TypeError:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\computation\expressions.py:239, in evaluate(op, a, b, use_numexpr)
#     <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/computation/expressions.py?line=236'>237</a>     if use_numexpr:
#     <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/computation/expressions.py?line=237'>238</a>         # error: "None" not callable
# --> <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/computation/expressions.py?line=238'>239</a>         return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/computation/expressions.py?line=239'>240</a> return _evaluate_standard(op, op_str, a, b)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\computation\expressions.py:69, in _evaluate_standard(op, op_str, a, b)
#      <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/computation/expressions.py?line=67'>68</a>     _store_test_result(False)
# ---> <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/computation/expressions.py?line=68'>69</a> return op(a, b)
#
# TypeError: unsupported operand type(s) for -: 'float' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# c:\Hacktiv8 FTDS 009\Live  Code\p0---ftds009---lc1-Luthfifadhlillah55\h8_p0lc1_Luthfi_Fadhlillah.ipynb Cell 40' in <module>
# ----> <a href='vscode-notebook-cell:/c%3A/Hacktiv8%20FTDS%20009/Live%20%20Code/p0---ftds009---lc1-Luthfifadhlillah55/h8_p0lc1_Luthfi_Fadhlillah.ipynb#ch0000041?line=0'>1</a> df.diff(axis=1)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:8526, in DataFrame.diff(self, periods, axis)
#    <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/frame.py?line=8523'>8524</a> axis = self._get_axis_number(axis)
#    <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/frame.py?line=8524'>8525</a> if axis == 1 and periods != 0:
# -> <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/frame.py?line=8525'>8526</a>     return self - self.shift(periods, axis=axis)
#    <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/frame.py?line=8527'>8528</a> new_data = self._mgr.diff(n=periods, axis=axis)
#    <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/frame.py?line=8528'>8529</a> return self._constructor(new_data).__finalize__(self, "diff")
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\ops\common.py:70, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/ops/common.py?line=65'>66</a>             return NotImplemented
#      <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/ops/common.py?line=67'>68</a> other = item_from_zerodim(other)
# ---> <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/ops/common.py?line=69'>70</a> return method(self, other)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\arraylike.py:108, in OpsMixin.__sub__(self, other)
#     <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/arraylike.py?line=105'>106</a> @unpack_zerodim_and_defer("__sub__")
#     <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/arraylike.py?line=106'>107</a> def __sub__(self, other):
# --> <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/arraylike.py?line=107'>108</a>     return self._arith_method(other, operator.sub)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:6940, in DataFrame._arith_method(self, other, op)
#    <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/frame.py?line=6935'>6936</a> other = ops.maybe_prepare_scalar_for_op(other, (self.shape[axis],))
#    <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/frame.py?line=6937'>6938</a> self, other = ops.align_method_FRAME(self, other, axis, flex=True, level=None)
# -> <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/frame.py?line=6939'>6940</a> new_data = self._dispatch_frame_op(other, op, axis=axis)
#    <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/frame.py?line=6940'>6941</a> return self._construct_result(new_data)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:6979, in DataFrame._dispatch_frame_op(self, right, func, axis)
#    <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/frame.py?line=6972'>6973</a>     # TODO: The previous assertion `assert right._indexed_same(self)`
#    <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/frame.py?line=6973'>6974</a>     #  fails in cases with empty columns reached via
#    <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/frame.py?line=6974'>6975</a>     #  _frame_arith_method_with_reindex
#    <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/frame.py?line=6975'>6976</a>
#    <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/frame.py?line=6976'>6977</a>     # TODO operate_blockwise expects a manager of the same type
#    <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/frame.py?line=6977'>6978</a>     with np.errstate(all="ignore"):
# -> <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/frame.py?line=6978'>6979</a>         bm = self._mgr.operate_blockwise(
#    <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/frame.py?line=6979'>6980</a>             # error: Argument 1 to "operate_blockwise" of "ArrayManager" has
#    <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/frame.py?line=6980'>6981</a>             # incompatible type "Union[ArrayManager, BlockManager]"; expected
#    <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/frame.py?line=6981'>6982</a>             # "ArrayManager"
#    <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/frame.py?line=6982'>6983</a>             # error: Argument 1 to "operate_blockwise" of "BlockManager" has
#    <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/frame.py?line=6983'>6984</a>             # incompatible type "Union[ArrayManager, BlockManager]"; expected
#    <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/frame.py?line=6984'>6985</a>             # "BlockManager"
#    <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/frame.py?line=6985'>6986</a>             right._mgr,  # type: ignore[arg-type]
#    <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/frame.py?line=6986'>6987</a>             array_op,
#    <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/frame.py?line=6987'>6988</a>         )
#    <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/frame.py?line=6988'>6989</a>     return self._constructor(bm)
#    <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/frame.py?line=6990'>6991</a> elif isinstance(right, Series) and axis == 1:
#    <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/frame.py?line=6991'>6992</a>     # axis=1 means we want to operate row-by-row
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\internals\managers.py:1409, in BlockManager.operate_blockwise(self, other, array_op)
#    <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/internals/managers.py?line=1404'>1405</a> def operate_blockwise(self, other: BlockManager, array_op) -> BlockManager:
#    <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/internals/managers.py?line=1405'>1406</a>     """
#    <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/internals/managers.py?line=1406'>1407</a>     Apply array_op blockwise with another (aligned) BlockManager.
#    <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/internals/managers.py?line=1407'>1408</a>     """
# -> <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/internals/managers.py?line=1408'>1409</a>     return operate_blockwise(self, other, array_op)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\internals\ops.py:63, in operate_blockwise(left, right, array_op)
#      <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/internals/ops.py?line=60'>61</a> res_blks: list[Block] = []
#      <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/internals/ops.py?line=61'>62</a> for lvals, rvals, locs, left_ea, right_ea, rblk in _iter_block_pairs(left, right):
# ---> <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/internals/ops.py?line=62'>63</a>     res_values = array_op(lvals, rvals)
#      <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/internals/ops.py?line=63'>64</a>     if left_ea and not right_ea and hasattr(res_values, "reshape"):
#      <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/internals/ops.py?line=64'>65</a>         res_values = res_values.reshape(1, -1)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\ops\array_ops.py:222, in arithmetic_op(left, right, op)
#     <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/ops/array_ops.py?line=216'>217</a> else:
#     <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/ops/array_ops.py?line=217'>218</a>     # TODO we should handle EAs consistently and move this check before the if/else
#     <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/ops/array_ops.py?line=218'>219</a>     # (https://github.com/pandas-dev/pandas/issues/41165)
#     <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/ops/array_ops.py?line=219'>220</a>     _bool_arith_check(op, left, right)
# --> <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/ops/array_ops.py?line=221'>222</a>     res_values = _na_arithmetic_op(left, right, op)
#     <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/ops/array_ops.py?line=223'>224</a> return res_values
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\ops\array_ops.py:170, in _na_arithmetic_op(left, right, op, is_cmp)
#     <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/ops/array_ops.py?line=163'>164</a> except TypeError:
#     <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/ops/array_ops.py?line=164'>165</a>     if not is_cmp and (is_object_dtype(left.dtype) or is_object_dtype(right)):
#     <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/ops/array_ops.py?line=165'>166</a>         # For object dtype, fallback to a masked operation (only operating
#     <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/ops/array_ops.py?line=166'>167</a>         #  on the non-missing values)
#     <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/ops/array_ops.py?line=167'>168</a>         # Don't do this for comparisons, as that will handle complex numbers
#     <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/ops/array_ops.py?line=168'>169</a>         #  incorrectly, see GH#32047
# --> <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/ops/array_ops.py?line=169'>170</a>         result = _masked_arith_op(left, right, op)
#     <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/ops/array_ops.py?line=170'>171</a>     else:
#     <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/ops/array_ops.py?line=171'>172</a>         raise
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\ops\array_ops.py:108, in _masked_arith_op(x, y, op)
#     <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/ops/array_ops.py?line=105'>106</a>     # See GH#5284, GH#5035, GH#19448 for historical reference
#     <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/ops/array_ops.py?line=106'>107</a>     if mask.any():
# --> <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/ops/array_ops.py?line=107'>108</a>         result[mask] = op(xrav[mask], yrav[mask])
#     <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/ops/array_ops.py?line=109'>110</a> else:
#     <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/ops/array_ops.py?line=110'>111</a>     if not is_scalar(y):
#
# TypeError: unsupported operand type(s) for -: 'float' and 'str'
